# %%
import pandas

# %%
df = pandas.read_csv("AuctionsExt.csv", sep=",", header=0)

# %%
display(df)
# Out:
#         Stock# Lane  Item#  Year      Make         Model                VIN  \
# 0     25045153    B     30  1997     ACURA         2.5TL  JH4UA2654VC005381
# 1     25150710    A   3052  2003     ACURA         3.2CL  19UYA41653A015099
# 2     25083174    A    123  2001     ACURA         3.2CL  19UYA42701A030243
# 3     24968306    A   3153  2006     ACURA         3.2TL  19UUA66286A013593
# 4     24890635    A   3320  2006     ACURA         3.2TL  19UUA662X6A048314
# 5     25001720    A     73  2003     ACURA         3.2TL  19UUA56873A045851
# 6     25031477    A    140  2003     ACURA         3.2TL  19UUA56783A045672
# 7     25081962    B   3312  2002     ACURA         3.2TL  19UUA56662A040427
# 8     25151957    A    183  2001     ACURA         3.2TL  19UUA56691A014631
# 9     25197608    A    120  2001     ACURA         3.2TL  19UUA56731A032924
# 10    24926939    B    148  2015     ACURA           ILX  19VDE2E50FE000219
# ...

# %%
df.iloc[29]
# Out:
# Stock#                           24751467
# Lane                                    A
# Item#                                 623
# Year                                 2015
# Make                                ACURA
# Model                                 RDX
# VIN                     5J8TB3H58FL018635
# Odometer                          39k mi
# Sale Document      SALVAGE CERTIFICATE-CA
# Loss Type                       COLLISION
# Auction Date         Mon Jun 03, 11am CDT
# Branch                          San Diego
# Public                                 NO
# Live online bid                        NO
# Name: 29, dtype: object
